# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Australia-Data" data-toc-modified-id="Australia-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Australia Data</a></span></li><li><span><a href="#Load-data" data-toc-modified-id="Load-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Fit-Model,-Make-Predictions" data-toc-modified-id="Fit-Model,-Make-Predictions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Fit Model, Make Predictions</a></span></li><li><span><a href="#Display-Actual-vs-Prediction" data-toc-modified-id="Display-Actual-vs-Prediction-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Display Actual vs Prediction</a></span></li><li><span><a href="#Commentary" data-toc-modified-id="Commentary-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Commentary</a></span><ul class="toc-item"><li><span><a href="#19th-Apr" data-toc-modified-id="19th-Apr-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>19th Apr</a></span></li><li><span><a href="#4th-Apr" data-toc-modified-id="4th-Apr-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>4th Apr</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Australia Data
# ## Load data

# %%
import sys
from os import path
sys.path.append(path.pardir)
from src.covid import CovidCountry
import pandas as pd

# Load data
country = 'Australia'
filepath = '../data/raw/'
fix_data = {'2020-04-19': 6612,}

au = CovidCountry(country=country,
                  filepath=filepath,
                  fixes=fix_data)

au.load(today=6619)

# %% [markdown]
# ## Fit Model, Make Predictions

# %%
au.fit(curve='gamma')
au_df = au.predict()
au.save(filepath='../data/processed/')

# %%
# Show small window of prediction and actual
au_df[pd.Timestamp.now().date()-pd.Timedelta('3D'):].diff()[1:6]
# Out:
#             Actual  Prediction
# Date
# 2020-04-18    25.0   21.308272
# 2020-04-19    65.0   17.583493
# 2020-04-20     7.0   14.513960
# 2020-04-21     NaN   11.997667
# 2020-04-22     NaN    9.944664

# %% [markdown]
# ## Display Actual vs Prediction

# %%
au.display(offset=42)

# %% [markdown]
# ## Commentary
# ### 19th Apr
# Australia is low and short. Given the scenes in March of people on beaches, this is very good.
#
# ### 4th Apr
# Australia has a low curve, even when adjusting for per capital.
