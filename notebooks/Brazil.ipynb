# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Brazil" data-toc-modified-id="Brazil-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Brazil</a></span></li><li><span><a href="#Load-data" data-toc-modified-id="Load-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Fit-and-Predict" data-toc-modified-id="Fit-and-Predict-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Fit and Predict</a></span></li><li><span><a href="#Display-Actual-vs-Prediction" data-toc-modified-id="Display-Actual-vs-Prediction-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Display Actual vs Prediction</a></span></li><li><span><a href="#Commentary" data-toc-modified-id="Commentary-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Commentary</a></span><ul class="toc-item"><li><span><a href="#21st-May" data-toc-modified-id="21st-May-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>21st May</a></span></li><li><span><a href="#15th-May" data-toc-modified-id="15th-May-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>15th May</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Brazil
#
# ## Load data

# %%
import sys
from os import path
sys.path.append(path.pardir)
from src.covid import CovidCountry
import pandas as pd

# Get our Country model data
country = 'Brazil'
filepath = '../data/raw/'

cty = CovidCountry(country=country,
                  filepath=filepath)
cty.load()

# %% [markdown]
# ## Fit and Predict

# %%
cty.fit(curve='gamma')
df = cty.predict()
cty.save(filepath='../data/processed/')

# %%
# Show small window of prediction and actual
df[pd.Timestamp.now().date()-pd.Timedelta('3D'):].diff()[1:6]
# Out:
#              Actual    Prediction
# Date
# 2020-05-19  16517.0  10396.787419
# 2020-05-20  19694.0  10438.456417
# 2020-05-21      NaN  10463.614789
# 2020-05-22      NaN  10472.529792
# 2020-05-23      NaN  10465.533613

# %% [markdown]
# ## Display Actual vs Prediction

# %%
cty.display(offset=84)

# %% [markdown]
# ## Commentary
# ### 21st May
# Tweaked model - longer duration, higher total cases. The next week or two is key for total model fit - if the peak cases keep increasing, then the total cases will be much higher.
#
# ### 15th May
# Added Brazil to modelling
