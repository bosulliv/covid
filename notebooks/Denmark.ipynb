# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Denmark-Data" data-toc-modified-id="Denmark-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Denmark Data</a></span></li><li><span><a href="#Load-data,-Fit-Model" data-toc-modified-id="Load-data,-Fit-Model-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load data, Fit Model</a></span></li><li><span><a href="#Display-Actual-vs-Prediction" data-toc-modified-id="Display-Actual-vs-Prediction-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Display Actual vs Prediction</a></span></li><li><span><a href="#Commentary" data-toc-modified-id="Commentary-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Commentary</a></span><ul class="toc-item"><li><span><a href="#26th-Apr" data-toc-modified-id="26th-Apr-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>26th Apr</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Denmark Data
# ## Load data, Fit Model

# %%
import sys
from os import path
sys.path.append(path.pardir)
from src.covid import CovidCountry
import pandas as pd

# Load data
country = 'Denmark'
filepath = '../data/raw/'
fix_data = {}

dk = CovidCountry(country=country,
                  filepath=filepath,
                  fixes=fix_data)

dk.load()

# %%
dk.fit(curve='gamma')
dk_df = dk.predict()
dk.save(filepath='../data/processed/')

# %%
# Show small window of prediction and actual
dk_df[pd.Timestamp.now().date()-pd.Timedelta('3D'):].diff()[1:6]
# Out:
#             Actual  Prediction
# Date
# 2020-08-18   115.0         NaN
# 2020-08-19    85.0         NaN

# %% [markdown]
# ## Display Actual vs Prediction

# %%
dk.display(offset=100)

# %% [markdown]
# ## Commentary
# ### 26th Apr
# Added today. The shape is unusual. The fit is not going to be brilliant, and will take a little while to tune a decent forecast for the downward slope.
